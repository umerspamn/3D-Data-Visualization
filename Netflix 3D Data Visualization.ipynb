# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import scipy as sc
import plotly.express as px

# %%
df=pd.read_csv("Netflix TV Shows and Movies.csv")

df.head(1)
# Out:
#    index       id        title   type  \
# 0      0  tm84618  Taxi Driver  MOVIE
#
#                                          description  release_year  \
# 0  A mentally unstable Vietnam War veteran works ...          1976
#
#   age_certification  runtime    imdb_id  imdb_score  imdb_votes
# 0                 R      113  tt0075314         8.3    795222.0

# %%
df1=df.groupby(["release_year","imdb_score"])

# %%
mn= np.array(df)
print(type(mn))
# Out:
# <class 'numpy.ndarray'>

# %%
mn.shape
# Out:
# (5283, 11)

# %%
# Out:
# dtype('O')

# %%
# Out:
# 58113

# %%
# Assuming y is a 2D NumPy array (matrix)
y = np.array([[1, 2, 3],
              [4, 5, 6]])

# Transpose of y
y_transpose = y.T

print("Original matrix (y):")
print(y)

print("\nTransposed matrix (y_transpose):")
print(y_transpose)
# Out:
# Original matrix (y):
# [[1 2 3]
#  [4 5 6]]
#
# Transposed matrix (y_transpose):
# [[1 4]
#  [2 5]
#  [3 6]]

# %%
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import axes3d
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# Create a sample 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Generate some random data for demonstration
sc=ax.scatter(df['imdb_score'], df['imdb_votes'], df['release_year'],
             c=df['imdb_score'], cmap='Reds', marker='o', alpha=0.8, edgecolors='w')
ax.set_xlabel('IMDb Score')
ax.set_ylabel('IMDb Votes')
ax.set_zlabel('Release Year')

plt.show()
